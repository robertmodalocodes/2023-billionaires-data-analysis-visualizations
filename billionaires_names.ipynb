# %% [markdown]
# # Billionaires dataset

# %% [markdown]
# ## Billionaires names

# %% [markdown]
# ---
#
# format: html
# echo: false
# warning: false
#
# ---
#
# # Billionaries

# %% [markdown]
# ::: {.content-hidden}
#
# :::

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from matplotlib.patches import Patch
import geopandas as gpd

# %matplotlib inline

pd.set_option("display.max_columns", None)
sns.set_style('darkgrid')

# %%
df_bill = pd.read_csv("./Billionaires Statistics Dataset.csv")

# %%
df_bill.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship                      organization  selfMade status  \
# ...

# %%
# Billionaires names
df_bill_names = df_bill.sort_values(by='finalWorth', ascending=False).copy()

# %%
df_bill_names.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship                      organization  selfMade status  \
# ...

# %%
df_bill_names.dtypes
# Out:
# rank                                            int64
# finalWorth                                      int64
# category                                       object
# personName                                     object
# age                                           float64
# country                                        object
# city                                           object
# source                                         object
# industries                                     object
# countryOfCitizenship                           object
# organization                                   object
# selfMade                                         bool
# status                                         object
# gender                                         object
# birthDate                                      object
# lastName                                       object
# firstName                                      object
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_bill_names.head(20), x='finalWorth', y='personName', hue='category', palette='tab10')
plt.title("Top 20 billionaires by industry", pad=20)
#plt.xticks([i for i in range(0, 12, 1)], [i for i in month_names.values()], rotation=0)
plt.ylabel('Billionaires', labelpad=15)
plt.xlabel('Final Worth (in million USD)', labelpad=15)
plt.legend(title="Industry")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_bill_names.head(20), x='finalWorth', y='personName', hue='country', palette='tab10')
plt.title("Top 20 billionaires by country", pad=20)
#plt.xticks([i for i in range(0, 12, 1)], [i for i in month_names.values()], rotation=0)
plt.ylabel('Billionaires', labelpad=15)
plt.xlabel('Final Worth (in million USD)', labelpad=15)
plt.legend(title="Country")
plt.show()

# %%
df_bill_names["state"] = df_bill_names["state"].fillna("Unknown")

# %%
df_bill_names["state"].unique()
# Out:
# array(['Unknown', 'Texas', 'Washington', 'Hawaii', 'Nebraska', 'New York',
#        'California', 'Kansas', 'Arkansas', 'Oregon', 'Virginia',
#        'Wyoming', 'Nevada', 'Florida', 'Pennsylvania', 'Massachusetts',
#        'Illinois', 'Tennessee', 'Connecticut', 'Oklahoma', 'Michigan',
#        'Wisconsin', 'Colorado', 'Indiana', 'New Hampshire', 'Georgia',
#        'Missouri', 'New Jersey', 'North Carolina', 'Iowa', 'Kentucky',
#        'Maryland', 'Montana', 'Ohio', 'South Carolina', 'Arizona',
#        'Louisiana', 'Utah', 'Rhode Island', 'Idaho',
#        'U.S. Virgin Islands', 'Minnesota', 'Maine', 'Mississippi',
#        'South Dakota', 'Alabama'], dtype=object)

# %%
df_bill_names
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2569  2540        1000  Finance & Investments           Sven Hagströmer  79.0
# 2568  2540        1000            Real Estate             Jianming Geng  60.0
# 2567  2540        1000          Manufacturing               Gao Yunfeng  56.0
# 2566  2540        1000       Fashion & Retail            William Fisher  66.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...
